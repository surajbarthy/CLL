# %%
from PIL import Image, ImageOps, ImageFilter

# %%
text_bytes = open("frost.txt", "rb").read()

# %%
width = 20 # arbitrary, adjust to taste
padded_text_bytes = text_bytes + (b' ' * width * 3)
height = int((len(padded_text_bytes) / 3) / width)

# %%
text_img = Image.frombytes('RGB', (width, height), padded_text_bytes)

# %%
text_img
# Out:
# <PIL.Image.Image image mode=RGB size=20x13>

# %%
def show_scaled(img, scale=8):
    return img.resize((img.width*scale, img.height*scale))

# %%
show_scaled(text_img)
# Out:
# <PIL.Image.Image image mode=RGB size=160x104>

# %%
text_img.save("text_img.png")

# %%
loaded = Image.open("text_img.png")

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# b'Two roads diverged in a yellow wood,\nAnd sorry I could not travel both\nAnd be one traveler, long I stood\nAnd looked down one as far as I could\nTo where it bent in the undergrowth;\n\nThen took the other, as just as fair,\nAnd having perhaps the better claim,\nBecause it was grassy and wanted wear;\nThough as for that the passing there\nHad worn them really about the same,\n\nAnd both that morning equally lay\nIn leaves no step had trodden black.\nOh, I kept the first for another day!\nYet knowing how way leads on to way,\nI doubted if I should ever come back.\n\nI shall be telling this with a sigh\nSomewhere ages and ages hence:\nTwo roads diverged in a wood, and I---\nI took the one less travelled by,\nAnd that has made all the difference.\n                                               '

# %%
# I took this image and inverted it

# %%
loaded = Image.open("text_img_invert.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=160x104>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# b'~\x9a\x8c~\x98\x88\x7f\x97\x88\x81\x96\x87\x86\x93\x87\x8a\x92\x87\x90\x90\x87\x96\x8d\x87\xa0\x8b\x86\xac\x88\x86\xb9\x85\x86\xc6\x83\x86\xd2\x7f\x88\xda~\x8a\xdf~\x8d
# ...

# %%
# I took the original image and made it greyscale

# %%
loaded = Image.open("text_img_greyscale.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=160x104>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# b'
# ...

# %%
# I took the images from last week and tried converting them to text

# %%
loaded = Image.open("p5exit256bw.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x1200>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Tried with a smaller image

# %%
loaded = Image.open("p5exit48bw.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x1200>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(img_bytes)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
NotebookApp.iopub_data_rate_limit=1.0e10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/c6/y8jxs3ls5dz3nj192z0h4s7m0000gn/T/ipykernel_9410/2902609944.py in <module>
# ----> 1 NotebookApp.iopub_data_rate_limit=1.0e10
#
# NameError: name 'NotebookApp' is not defined

# %%
--generate-config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/c6/y8jxs3ls5dz3nj192z0h4s7m0000gn/T/ipykernel_9410/629263120.py in <module>
# ----> 1 --generate-config
#
# NameError: name 'generate' is not defined

# %%
# Using https://stackoverflow.com/questions/43288550/iopub-data-rate-exceeded-in-jupyter-notebook-when-viewing-image

# %%
# Tried on terminal too

# %%
# Didn't work. I am doing something wrong. Made another version of the file 20x20

# %%
loaded = Image.open("p5exit20bw.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=20x20>

# %%
def show_scaled(img, scale=8):
    return img.resize((img.width*scale, img.height*scale))

# %%
show_scaled(loaded)
# Out:
# <PIL.Image.Image image mode=RGBA size=160x160>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# b'333\xe5,,,\xf2***\xf2(((\xf2%%%\xf2///\xf2<<<\xf2333\xf2---\xf2(((\xf2***\xf2"""\xf2\x13\x13\x13\xf2\x0b\x0b\x0b\xf2\x05\x05\x05\xf2\x0c\x0c\x0c\xf2\x14\x14\x14\xf2\x12\x12\x12\xf2\x0f\x0f\x0f\xf2\x12\x12\x12\xe5%%%\xff"""\xff!!!\xff###\xff!!!\xff...\xff...\xff)))\xff"""\xff\x18\x18\x18\xff\x15\x15\x15\xff\x0c\x0c\x0c\xff\x03\x03\x03\xff\x05\x05\x05\xff\x15\x15\x15\xff\x11\x11\x11\xff\x04\x04\x04\xff\x0f\x0f\x0f\xff\x0f\x0f\x0f\xff\x0e\x0e\x0e\xff"""\xf2///\xff222\xff---\xff)))\xff!!!\xff\x13\x13\x13\xff\x11\x11\x11\xff\x16\x16\x16\xff\x0b\x0b\x0b\xff\x01\x01\x01\xff\x04\x04\x04\xff\t\t\t\xff\x15\x15\x15\xff777\xff???\xff\x16\x16\x16\xff\x08\x08\x08\xff\r\r\r\xff\x0c\x0c\x0c\xf2+++\xf2&&&\xff!!!\xff\x19\x19\x19\xff\x15\x15\x15\xff\x12\x12\x12\xff\x0e\x0e\x0e\xff\x11\x11\x11\xff\x11\x11\x11\xff\t\t\t\xff\x08\x08\x08\xff\x07\x07\x07\xff\x08\x08\x08\xff\x0f\x0f\x0f\xff333\xffEEE\xff\x18\x18\x18\xff\x03\x03\x03\xff\x07\x07\x07\xff\t\t\t\xf2   \xf2\x17\x17\x17\xff\x13\x13\x13\xff\x10\x1
# ...

# %%
# I checked and realised that the 48bw version was also 1200x1200 pixels. My bad!

# %%
# I tried it with the other image from last week too.

# %%
loaded = Image.open("p548bw.png")

# %%
loaded
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=48x48>

# %%
def show_scaled(img, scale=8):
    return img.resize((img.width*scale, img.height*scale))

# %%
show_scaled(loaded)
# Out:
# <PIL.Image.Image image mode=RGBA size=384x384>

# %%
img_bytes = loaded.tobytes()

# %%
print(img_bytes)
# Out:
# b'===\xe5<<<\xf2###\xf2&&&\xf2999\xf2222\xf2333\xf2222\xf2333\xf2222\xf2111\xf2333\xf2444\xf2222\xf2666\xf2<<<\xf2>>>\xf2@@@\xf2---\xf2\x14\x14\x14\xf2:::\xf2===\xf2:::\xf2<<<\xf2;;;\xf2444\xf2555\xf2888\xf2333\xf2222\xf2444\xf2333\xf2333\xf2222\xf2222\xf2333\xf2333\xf2333\xf2222\xf2333\xf2222\xf2333\xf2888\xf2@@@\xf2@@@\xf2DDD\xf2>>>\xf2888\xe5XXX\xffPPP\xff\x1f\x1f\x1f\xff\x1f\x1f\x1f\xff;;;\xff:::\xff777\xff777\xff777\xff888\xff777\xff666\xff999\xff666\xff666\xff777\xff===\xffBBB\xff,,,\xff\x14\x14\x14\xff888\xffBBB\xff===\xff;;;\xff777\xff666\xff888\xff555\xff555\xff999\xff;;;\xff;;;\xff777\xff666\xff777\xff777\xff777\xff777\xff666\xff777\xff555\xff999\xffBBB\xffDDD\xff@@@\xff999\xff===\xffDDD\xfffff\xf2aaa\xff,,,\xff\x16\x16\x16\xff000\xff;;;\xff444\xff444\xff555\xff555\xff555\xff444\xff555\xff444\xff555\xff555\xff444\xff???\xff)))\xff\x14\x14\x14\xff666\xff666\xff888\xff:::\xffEEE\xff???\xff777\xff777\xff888\xff;;;\xff444\xff111\xff555\xff<<<\xff:::\xff:::\xff;;;\xff:::\xff:::\
# ...

# %%
# I would like to work with audio and test out that part of the notebook too. 🎼
## I want to use movie screenplays and do something with them. 📽️
### I will continue working on this notebook this week. 📆
